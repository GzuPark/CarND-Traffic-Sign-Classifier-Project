# %%
# Load pickled data
import pickle

training_file   = 'traffic-signs-data/train.p'
validation_file = 'traffic-signs-data/valid.p'
testing_file    = 'traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
import numpy as np
from sklearn.utils import shuffle

X_train_gray = np.dot(X_train[...,:3], [[0.299], [0.587], [0.114]])
X_valid_gray = np.dot(X_valid[...,:3], [[0.299], [0.587], [0.114]])
X_test_gray = np.dot(X_test[...,:3], [[0.299], [0.587], [0.114]])

X_train, y_train = shuffle(X_train_gray, y_train)
X_valid, y_valid = shuffle(X_valid_gray, y_valid)
X_test, y_test = shuffle(X_test_gray, y_test)

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
import tensorflow as tf
from tensorflow.contrib.layers import flatten

def LeNet_1(x, sigma):
    mu = 0
    sigma = sigma
    ksize = 5
    n_classes = 43
    conv1_d = 8
    conv2_d = 32
    
    # from (32, 32, 1) to (28, 28, 8)
    conv1_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, 1, conv1_d), mean=mu, stddev=sigma))
    conv1_b = tf.Variable(tf.zeros(conv1_d))
    conv1 = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding="VALID") + conv1_b
    conv1 = tf.nn.relu(conv1)
    # from (28, 28, 8) to (14, 14, 8)
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # from (14, 14, 8) to (10, 10, 32)
    conv2_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, conv1_d, conv2_d), mean=mu, stddev=sigma))
    conv2_b = tf.Variable(tf.zeros(conv2_d))
    conv2 = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding="VALID") + conv2_b
    conv2 = tf.nn.relu(conv2)
    # from (10, 10, 32) to (5, 5, 32)
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # flatten 5x5x32 = 800
    fc0 = flatten(conv2)
    
    # from 800 to 512
    fc1_W = tf.Variable(tf.truncated_normal(shape=(800, 512), mean=mu, stddev=sigma))
    fc1_b = tf.Variable(tf.zeros(512))
    fc1 = tf.matmul(fc0, fc1_W) + fc1_b
    fc1 = tf.nn.relu(fc1)
    
    # from 512 to 256
    fc2_W = tf.Variable(tf.truncated_normal(shape=(512, 256), mean=mu, stddev=sigma))
    fc2_b = tf.Variable(tf.zeros(256))
    fc2 = tf.matmul(fc1, fc2_W) + fc2_b
    fc2 = tf.nn.relu(fc2)
    
    # from 256 to 43
    fc3_W = tf.Variable(tf.truncated_normal(shape=(256, n_classes), mean=mu, stddev=sigma))
    fc3_b = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.880
#
# EPOCH 2 ...
# Validation Accuracy = 0.914
#
# EPOCH 3 ...
# Validation Accuracy = 0.912
#
# EPOCH 4 ...
# Validation Accuracy = 0.911
#
# EPOCH 5 ...
# Validation Accuracy = 0.919
#
# EPOCH 6 ...
# Validation Accuracy = 0.928
#
# EPOCH 7 ...
# Validation Accuracy = 0.937
#
# EPOCH 8 ...
# Validation Accuracy = 0.936
#
# EPOCH 9 ...
# Validation Accuracy = 0.946
#
# EPOCH 10 ...
# Validation Accuracy = 0.921
#
# Max Accuracy: 0.946031746302
# Test Accuracy = 0.908
# Total time is: 277.1111550331116

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.05)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.904
#
# EPOCH 2 ...
# Validation Accuracy = 0.896
#
# EPOCH 3 ...
# Validation Accuracy = 0.916
#
# EPOCH 4 ...
# Validation Accuracy = 0.917
#
# EPOCH 5 ...
# Validation Accuracy = 0.924
#
# EPOCH 6 ...
# Validation Accuracy = 0.936
#
# EPOCH 7 ...
# Validation Accuracy = 0.944
#
# EPOCH 8 ...
# Validation Accuracy = 0.920
#
# EPOCH 9 ...
# Validation Accuracy = 0.927
#
# EPOCH 10 ...
# Validation Accuracy = 0.939
#
# Max Accuracy: 0.944444444715
# Test Accuracy = 0.927
# Total time is: 272.97228813171387

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.1)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.751
#
# EPOCH 2 ...
# Validation Accuracy = 0.807
#
# EPOCH 3 ...
# Validation Accuracy = 0.830
#
# EPOCH 4 ...
# Validation Accuracy = 0.829
#
# EPOCH 5 ...
# Validation Accuracy = 0.844
#
# EPOCH 6 ...
# Validation Accuracy = 0.827
#
# EPOCH 7 ...
# Validation Accuracy = 0.855
#
# EPOCH 8 ...
# Validation Accuracy = 0.863
#
# EPOCH 9 ...
# Validation Accuracy = 0.837
#
# EPOCH 10 ...
# Validation Accuracy = 0.866
#
# Max Accuracy: 0.866439909054
# Test Accuracy = 0.854
# Total time is: 265.67023277282715

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.01)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.805
#
# EPOCH 2 ...
# Validation Accuracy = 0.890
#
# EPOCH 3 ...
# Validation Accuracy = 0.919
#
# EPOCH 4 ...
# Validation Accuracy = 0.907
#
# EPOCH 5 ...
# Validation Accuracy = 0.910
#
# EPOCH 6 ...
# Validation Accuracy = 0.912
#
# EPOCH 7 ...
# Validation Accuracy = 0.931
#
# EPOCH 8 ...
# Validation Accuracy = 0.931
#
# EPOCH 9 ...
# Validation Accuracy = 0.931
#
# EPOCH 10 ...
# Validation Accuracy = 0.934
#
# Max Accuracy: 0.934240362839
# Test Accuracy = 0.923
# Total time is: 271.8083109855652

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
import tensorflow as tf
from tensorflow.contrib.layers import flatten

def LeNet_2(x):
    mu = 0
    sigma = 0.03
    ksize = 3
    n_classes = 43
    conv1_d = 8
    conv2_d = 32
    
    # from (32, 32, 1) to (30, 30, 8)
    conv1_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, 1, conv1_d), mean=mu, stddev=sigma))
    conv1_b = tf.Variable(tf.zeros(conv1_d))
    conv1 = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding="VALID") + conv1_b
    conv1 = tf.nn.relu(conv1)
    # from (30, 30, 8) to (15, 15, 8)
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # from (15, 15, 8) to (13, 13, 32)
    conv2_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, conv1_d, conv2_d), mean=mu, stddev=sigma))
    conv2_b = tf.Variable(tf.zeros(conv2_d))
    conv2 = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding="VALID") + conv2_b
    conv2 = tf.nn.relu(conv2)
    # from (13, 13, 32) to (6, 6, 32)
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # flatten 6x6x32 = 1152
    fc0 = flatten(conv2)
    
    # from 1152 to 1024
    fc1_W = tf.Variable(tf.truncated_normal(shape=(1152, 1024), mean=mu, stddev=sigma))
    fc1_b = tf.Variable(tf.zeros(1024))
    fc1 = tf.matmul(fc0, fc1_W) + fc1_b
    fc1 = tf.nn.relu(fc1)
    
    # from 1024 to 512
    fc2_W = tf.Variable(tf.truncated_normal(shape=(1024, 512), mean=mu, stddev=sigma))
    fc2_b = tf.Variable(tf.zeros(512))
    fc2 = tf.matmul(fc1, fc2_W) + fc2_b
    fc2 = tf.nn.relu(fc2)
    
    # from 512 to 43
    fc3_W = tf.Variable(tf.truncated_normal(shape=(512, n_classes), mean=mu, stddev=sigma))
    fc3_b = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_2(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.885
#
# EPOCH 2 ...
# Validation Accuracy = 0.905
#
# EPOCH 3 ...
# Validation Accuracy = 0.936
#
# EPOCH 4 ...
# Validation Accuracy = 0.927
#
# EPOCH 5 ...
# Validation Accuracy = 0.931
#
# EPOCH 6 ...
# Validation Accuracy = 0.931
#
# EPOCH 7 ...
# Validation Accuracy = 0.944
#
# EPOCH 8 ...
# Validation Accuracy = 0.931
#
# EPOCH 9 ...
# Validation Accuracy = 0.932
#
# EPOCH 10 ...
# Validation Accuracy = 0.910
#
# Max Accuracy: 0.944217687075
# Test Accuracy = 0.906
# Total time is: 285.77780508995056

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.
import tensorflow as tf
from tensorflow.contrib.layers import flatten

def LeNet_3(x):
    mu = 0
    sigma = 0.03
    ksize = 5
    n_classes = 43
    conv1_d = 6
    conv2_d = 25
    
    # from (32, 32, 1) to (28, 28, 6)
    conv1_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, 1, conv1_d), mean=mu, stddev=sigma))
    conv1_b = tf.Variable(tf.zeros(conv1_d))
    conv1 = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding="VALID") + conv1_b
    conv1 = tf.nn.relu(conv1)
    # from (28, 28, 6) to (14, 14, 6)
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # from (14, 14, 6) to (10, 10, 25)
    conv2_W = tf.Variable(tf.truncated_normal(shape=(ksize, ksize, conv1_d, conv2_d), mean=mu, stddev=sigma))
    conv2_b = tf.Variable(tf.zeros(conv2_d))
    conv2 = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding="VALID") + conv2_b
    conv2 = tf.nn.relu(conv2)
    # from (5, 5, 25) to (5, 5, 25)
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    
    # flatten 5x5x25 = 625
    fc0 = flatten(conv2)
    
    # from 625 to 512
    fc1_W = tf.Variable(tf.truncated_normal(shape=(625, 512), mean=mu, stddev=sigma))
    fc1_b = tf.Variable(tf.zeros(512))
    fc1 = tf.matmul(fc0, fc1_W) + fc1_b
    fc1 = tf.nn.relu(fc1)
    
    # from 512 to 256
    fc2_W = tf.Variable(tf.truncated_normal(shape=(512, 256), mean=mu, stddev=sigma))
    fc2_b = tf.Variable(tf.zeros(256))
    fc2 = tf.matmul(fc1, fc2_W) + fc2_b
    fc2 = tf.nn.relu(fc2)
    
    # from 256 to 43
    fc3_W = tf.Variable(tf.truncated_normal(shape=(256, n_classes), mean=mu, stddev=sigma))
    fc3_b = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_3(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.863
#
# EPOCH 2 ...
# Validation Accuracy = 0.904
#
# EPOCH 3 ...
# Validation Accuracy = 0.921
#
# EPOCH 4 ...
# Validation Accuracy = 0.929
#
# EPOCH 5 ...
# Validation Accuracy = 0.937
#
# EPOCH 6 ...
# Validation Accuracy = 0.938
#
# EPOCH 7 ...
# Validation Accuracy = 0.929
#
# EPOCH 8 ...
# Validation Accuracy = 0.934
#
# EPOCH 9 ...
# Validation Accuracy = 0.915
#
# EPOCH 10 ...
# Validation Accuracy = 0.935
#
# Max Accuracy: 0.937868480996
# Test Accuracy = 0.924
# Total time is: 254.80971598625183

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 5
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.868
#
# EPOCH 2 ...
# Validation Accuracy = 0.899
#
# EPOCH 3 ...
# Validation Accuracy = 0.902
#
# EPOCH 4 ...
# Validation Accuracy = 0.941
#
# EPOCH 5 ...
# Validation Accuracy = 0.930
#
# Max Accuracy: 0.941043083657
# Test Accuracy = 0.912
# Total time is: 144.58003783226013

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 15
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.879
#
# EPOCH 2 ...
# Validation Accuracy = 0.903
#
# EPOCH 3 ...
# Validation Accuracy = 0.908
#
# EPOCH 4 ...
# Validation Accuracy = 0.893
#
# EPOCH 5 ...
# Validation Accuracy = 0.924
#
# EPOCH 6 ...
# Validation Accuracy = 0.930
#
# EPOCH 7 ...
# Validation Accuracy = 0.913
#
# EPOCH 8 ...
# Validation Accuracy = 0.935
#
# EPOCH 9 ...
# Validation Accuracy = 0.918
#
# EPOCH 10 ...
# Validation Accuracy = 0.931
#
# EPOCH 11 ...
# Validation Accuracy = 0.931
#
# EPOCH 12 ...
# Validation Accuracy = 0.931
#
# EPOCH 13 ...
# Validation Accuracy = 0.941
#
# EPOCH 14 ...
# Validation Accuracy = 0.940
#
# EPOCH 15 ...
# Validation Accuracy = 0.919
#
# Max Accuracy: 0.941043083927
# Test Accuracy = 0.918
# Total time is: 430.6324701309204

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 64

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.883
#
# EPOCH 2 ...
# Validation Accuracy = 0.910
#
# EPOCH 3 ...
# Validation Accuracy = 0.930
#
# EPOCH 4 ...
# Validation Accuracy = 0.920
#
# EPOCH 5 ...
# Validation Accuracy = 0.934
#
# EPOCH 6 ...
# Validation Accuracy = 0.942
#
# EPOCH 7 ...
# Validation Accuracy = 0.934
#
# EPOCH 8 ...
# Validation Accuracy = 0.939
#
# EPOCH 9 ...
# Validation Accuracy = 0.941
#
# EPOCH 10 ...
# Validation Accuracy = 0.931
#
# Max Accuracy: 0.942403627875
# Test Accuracy = 0.923
# Total time is: 314.3167190551758

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 256

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.001

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.858
#
# EPOCH 2 ...
# Validation Accuracy = 0.905
#
# EPOCH 3 ...
# Validation Accuracy = 0.917
#
# EPOCH 4 ...
# Validation Accuracy = 0.942
#
# EPOCH 5 ...
# Validation Accuracy = 0.937
#
# EPOCH 6 ...
# Validation Accuracy = 0.926
#
# EPOCH 7 ...
# Validation Accuracy = 0.932
#
# EPOCH 8 ...
# Validation Accuracy = 0.930
#
# EPOCH 9 ...
# Validation Accuracy = 0.932
#
# EPOCH 10 ...
# Validation Accuracy = 0.951
#
# Max Accuracy: 0.95079365055
# Test Accuracy = 0.917
# Total time is: 289.7707200050354

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.003

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.787
#
# EPOCH 2 ...
# Validation Accuracy = 0.882
#
# EPOCH 3 ...
# Validation Accuracy = 0.884
#
# EPOCH 4 ...
# Validation Accuracy = 0.883
#
# EPOCH 5 ...
# Validation Accuracy = 0.898
#
# EPOCH 6 ...
# Validation Accuracy = 0.866
#
# EPOCH 7 ...
# Validation Accuracy = 0.885
#
# EPOCH 8 ...
# Validation Accuracy = 0.885
#
# EPOCH 9 ...
# Validation Accuracy = 0.880
#
# EPOCH 10 ...
# Validation Accuracy = 0.882
#
# Max Accuracy: 0.897959183971
# Test Accuracy = 0.869
# Total time is: 277.56956911087036

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import time

start = time.time()

EPOCHS = 10
BATCH_SIZE = 128

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

rate = 0.0005

logits = LeNet_1(x, 0.03)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    max_accuracy = 0
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        if validation_accuracy > max_accuracy:
            max_accuracy = validation_accuracy
            
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    print("Max Accuracy:", max_accuracy)
    
    test_accuracy = sess.run(accuracy_operation, feed_dict={x: X_test, y: y_test})
    print("Test Accuracy = {:.3f}".format(test_accuracy))

done = time.time()

print("Total time is: {}".format(done - start))
# Out:
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.860
#
# EPOCH 2 ...
# Validation Accuracy = 0.885
#
# EPOCH 3 ...
# Validation Accuracy = 0.925
#
# EPOCH 4 ...
# Validation Accuracy = 0.917
#
# EPOCH 5 ...
# Validation Accuracy = 0.919
#
# EPOCH 6 ...
# Validation Accuracy = 0.913
#
# EPOCH 7 ...
# Validation Accuracy = 0.926
#
# EPOCH 8 ...
# Validation Accuracy = 0.937
#
# EPOCH 9 ...
# Validation Accuracy = 0.935
#
# EPOCH 10 ...
# Validation Accuracy = 0.911
#
# Max Accuracy: 0.936961451517
# Test Accuracy = 0.903
# Total time is: 290.511039018631
